# %%
import pandas as pd
pd.read_csv("/content/drive/MyDrive/udmy/dataAnalisys/Cities.csv")
# Out:
#               City     Country  Population
# 0           Kajuru    Botswana       21722
# 1             Leon       Spain        5629
# 2              Osh  kyrgyzstan        5679
# 3    Shumikhinskiy      Russia       10085
# 4         Bundoran     Ireland       23421
# ..             ...         ...         ...
# 596        Lobitos        Peru       10024
# 597         Bremen     Germany        5768
# 598         Harare    Zimbabwe       16679
# 599          Lagos     Nigeria       24800
# 600         Oshawa      Canada       13000
#
# [601 rows x 3 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Sección nueva

# %%
cities = pd.read_csv("/content/drive/MyDrive/udmy/dataAnalisys/Cities.csv", usecols = ["City"])
pop = pd.read_csv("/content/drive/MyDrive/udmy/dataAnalisys/Cities.csv", usecols = ["Population"])
cities.tail(10)
pop.tail(10)
# Out:
#      Population
# 591       11949
# 592        4114
# 593       16755
# 594       16325
# 595       16905
# 596       10024
# 597        5768
# 598       16679
# 599       24800
# 600       13000

# %%
pop.tail()
# Out:
#      Population
# 596       10024
# 597        5768
# 598       16679
# 599       24800
# 600       13000

# %%
cities.head(30)
# Out:
#               City
# 0           Kajuru
# 1             Leon
# 2              Osh
# 3    Shumikhinskiy
# 4         Bundoran
# 5        La Paloma
# 6            Tutup
# 7          Ondores
# 8          Heredia
# 9             Gaio
# 10             Ise
# 11          Volovo
# 12          Caujul
# 13      Kutloanong
# 14        Kobuleti
# 15          Senlis
# 16          Wufeng
# 17          Picton
# 18     Johor Bahru
# 19      Fort Worth
# 20      Santa Cruz
# 21    Lope de Vega
# 22          Maubin
# 23      El Crucero
# 24           Itzer
# 25            Erqu
# 26   Los Cerrillos
# 27           Uptar
# 28    Ponta do Sol
# 29  Boca de Uchire

# %%
pop.head(n = 8)
# Out:
#    Population
# 0       21722
# 1        5629
# 2        5679
# 3       10085
# 4       23421
# 5       22154
# 6       11558
# 7       13288

# %%
cities.count()
# Out:
# City    601
# dtype: int64

# %%
pop.count()
# Out:
# Population    601
# dtype: int64

# %%
cities.describe()
# Out:
#                City
# count           601
# unique          578
# top     San Antonio
# freq              4

# %%
pop.describe()
# Out:
#          Population
# count    601.000000
# mean   13932.415973
# std     6765.873291
# min     2528.000000
# 25%     7801.000000
# 50%    13966.000000
# 75%    19752.000000
# max    38745.000000

# %%
#cities.sort_values()
cities.sort_values(by = ["City"], ascending = True )
# Out:
#               City
# 581          Abuja
# 66          Aizhai
# 472          Aketi
# 212       Alarobia
# 467       Alcoutim
# ..             ...
# 386  Zhongshangang
# 69   Zhongshangang
# 427      Zhongxing
# 538       Zhuoshui
# 362           Zliv
#
# [601 rows x 1 columns]

# %%
cities.sort_values(by = ["City"], ascending = False).head()
# Out:
#               City
# 362           Zliv
# 538       Zhuoshui
# 427      Zhongxing
# 386  Zhongshangang
# 69   Zhongshangang

# %%
cities = pd.read_csv("/content/drive/MyDrive/udmy/dataAnalisys/Cities.csv", usecols = ["City"])
cities
cities.sort_values(by = ["City"], ascending = False, inplace = True)
cities
# Out:
#               City
# 362           Zliv
# 538       Zhuoshui
# 427      Zhongxing
# 386  Zhongshangang
# 69   Zhongshangang
# ..             ...
# 467       Alcoutim
# 212       Alarobia
# 472          Aketi
# 66          Aizhai
# 581          Abuja
#
# [601 rows x 1 columns]

# %%
cities.sort_index(inplace=True)
cities
# Out:
#               City
# 0           Kajuru
# 1             Leon
# 2              Osh
# 3    Shumikhinskiy
# 4         Bundoran
# ..             ...
# 596        Lobitos
# 597         Bremen
# 598         Harare
# 599          Lagos
# 600         Oshawa
#
# [601 rows x 1 columns]

# %%
#cities
cities = pd.read_csv("/content/drive/MyDrive/udmy/dataAnalisys/Cities.csv")
cities.sort_index(ascending = False, inplace = True)
cities
# Out:
#               City     Country  Population
# 600         Oshawa      Canada       13000
# 599          Lagos     Nigeria       24800
# 598         Harare    Zimbabwe       16679
# 597         Bremen     Germany        5768
# 596        Lobitos        Peru       10024
# ..             ...         ...         ...
# 4         Bundoran     Ireland       23421
# 3    Shumikhinskiy      Russia       10085
# 2              Osh  kyrgyzstan        5679
# 1             Leon       Spain        5629
# 0           Kajuru    Botswana       21722
#
# [601 rows x 3 columns]

# %%
print(cities)
# Out:
#               City     Country  Population
# 600         Oshawa      Canada       13000
# 599          Lagos     Nigeria       24800
# 598         Harare    Zimbabwe       16679
# 597         Bremen     Germany        5768
# 596        Lobitos        Peru       10024
# ..             ...         ...         ...
# 4         Bundoran     Ireland       23421
# 3    Shumikhinskiy      Russia       10085
# 2              Osh  kyrgyzstan        5679
# 1             Leon       Spain        5629
# 0           Kajuru    Botswana       21722
#
# [601 rows x 3 columns]

# %%
data = pd.read_csv("/content/drive/MyDrive/udmy/dataAnalisys/Cities.csv")
data
# Out:
#               City     Country  Population
# 0           Kajuru    Botswana       21722
# 1             Leon       Spain        5629
# 2              Osh  kyrgyzstan        5679
# 3    Shumikhinskiy      Russia       10085
# 4         Bundoran     Ireland       23421
# ..             ...         ...         ...
# 596        Lobitos        Peru       10024
# 597         Bremen     Germany        5768
# 598         Harare    Zimbabwe       16679
# 599          Lagos     Nigeria       24800
# 600         Oshawa      Canada       13000
#
# [601 rows x 3 columns]

# %%
data = pd.read_csv("/content/drive/MyDrive/udmy/dataAnalisys/Cities.csv", index_col = ["City"])
data = pd.read_csv("/content/drive/MyDrive/udmy/dataAnalisys/Cities.csv", usecols = ["City"], index_col = ["City"])
#data = pd.read_csv("/content/drive/MyDrive/udmy/dataAnalisys/Cities.csv")
data.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [Kajuru, Leon, Osh, Shumikhinskiy, Bundoran]

# %%
data = pd.read_csv("/content/drive/MyDrive/udmy/dataAnalisys/Cities.csv", usecols = ["City"])
city = data["City"]
city.get(3)
# Out:
# 'Shumikhinskiy'

# %%
data = pd.read_csv("/content/drive/MyDrive/udmy/dataAnalisys/Cities.csv")
poblacion = data["Population"]
print(poblacion)
#cities.head()
# Out:
# 0      21722
# 1       5629
# 2       5679
# 3      10085
# 4      23421
#        ...
# 596    10024
# 597     5768
# 598    16679
# 599    24800
# 600    13000
# Name: Population, Length: 601, dtype: int64

# %%
cities = pd.read_csv("/content/drive/MyDrive/udmy/dataAnalisys/Cities.csv", usecols=["City"], index_col=["City"])
cities.iloc[7]
# Out:
# Series([], Name: Ondores, dtype: float64)

# %%
cities[10:20]
# Out:
# 10            Ise
# 11         Volovo
# 12         Caujul
# 13     Kutloanong
# 14       Kobuleti
# 15         Senlis
# 16         Wufeng
# 17         Picton
# 18    Johor Bahru
# 19     Fort Worth
# Name: City, dtype: object

# %%
cities[:15]
# Out:
# 0            Kajuru
# 1              Leon
# 2               Osh
# 3     Shumikhinskiy
# 4          Bundoran
# 5         La Paloma
# 6             Tutup
# 7           Ondores
# 8           Heredia
# 9              Gaio
# 10              Ise
# 11           Volovo
# 12           Caujul
# 13       Kutloanong
# 14         Kobuleti
# Name: City, dtype: object

# %%
cities[:26:2]
# Out:
# 0          Kajuru
# 2             Osh
# 4        Bundoran
# 6           Tutup
# 8         Heredia
# 10            Ise
# 12         Caujul
# 14       Kobuleti
# 16         Wufeng
# 18    Johor Bahru
# 20     Santa Cruz
# 22         Maubin
# 24          Itzer
# Name: City, dtype: object

# %%
cities[-10:]
# Out:
# 591    Bagumbayan
# 592      Tuanshan
# 593       Sapporo
# 594    Cocachacra
# 595        Kurjan
# 596       Lobitos
# 597        Bremen
# 598        Harare
# 599         Lagos
# 600        Oshawa
# Name: City, dtype: object

# %%
cities[[3, 5, 7]]
#cities.sort_values()
# Out:
# 3    Shumikhinskiy
# 5        La Paloma
# 7          Ondores
# Name: City, dtype: object

# %%
#Retrieving data from a series by index label:

#city = pd.read_csv("Cities.csv", usecols = ["City", "Country"])
city = pd.read_csv("/content/drive/MyDrive/udmy/dataAnalisys/Cities.csv", usecols = ["City", "Country"], index_col = "City")
city = city["Country"]
city
# Out:
# City
# Kajuru             Botswana
# Leon                  Spain
# Osh              kyrgyzstan
# Shumikhinskiy        Russia
# Bundoran            Ireland
#                     ...
# Lobitos                Peru
# Bremen              Germany
# Harare             Zimbabwe
# Lagos               Nigeria
# Oshawa               Canada
# Name: Country, Length: 601, dtype: object

# %%
city[0]
# Out:
# <ipython-input-29-8f5a1a4338dc>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   city[0]
# 'Botswana'

# %%
city["Lobitos"]
# Out:
# City
# Lobitos    Peru
# Lobitos    Peru
# Name: Country, dtype: object

# %%
city["Kajuru"]
# Out:
# 'Botswana'

# %%
city.sort_index(inplace = True, ascending = True)
city
# Out:
# City
# Abuja                                     Nigeria
# Aizhai                                      China
# Aketi            Democratic Republic of the Congo
# Alarobia                               Madagascar
# Alcoutim                                 Portugal
#                                ...
# Zhongshangang                               China
# Zhongshangang                               China
# Zhongxing                                   China
# Zhuoshui                                    China
# Zliv                               Czech Republic
# Name: Country, Length: 601, dtype: object

# %%
city["Abuja":"Bremen"]
# Out:
# City
# Abuja                                 Nigeria
# Aizhai                                  China
# Aketi        Democratic Republic of the Congo
# Alarobia                           Madagascar
# Alcoutim                             Portugal
#                            ...
# Bolgar                                 Russia
# Bomomani                            Indonesia
# Bonavista                              Canada
# Bradag                              Indonesia
# Bremen                                Germany
# Name: Country, Length: 84, dtype: object

# %%
city[:"Bremen"]
# Out:
# City
# Abuja                                 Nigeria
# Aizhai                                  China
# Aketi        Democratic Republic of the Congo
# Alarobia                           Madagascar
# Alcoutim                             Portugal
#                            ...
# Bolgar                                 Russia
# Bomomani                            Indonesia
# Bonavista                              Canada
# Bradag                              Indonesia
# Bremen                                Germany
# Name: Country, Length: 84, dtype: object

# %%
city[["Bolgar", "Abuja", "Osh"]]
# Out:
# City
# Bolgar        Russia
# Abuja        Nigeria
# Osh       kyrgyzstan
# Name: Country, dtype: object

# %%
city.head(10)
# Out:
# City
# Abuja                                      Nigeria
# Aizhai                                       China
# Aketi             Democratic Republic of the Congo
# Alarobia                                Madagascar
# Alcoutim                                  Portugal
# Alis                                          Peru
# Alvaro Obregon                              Mexico
# Amargosa                                    Brazil
# Amuru                                       Uganda
# Anan                                         Japan
# Name: Country, dtype: object

# %%
city["Abuja": "Anan": 2]
# Out:
# City
# Abuja                                      Nigeria
# Aketi             Democratic Republic of the Congo
# Alcoutim                                  Portugal
# Alvaro Obregon                              Mexico
# Amuru                                       Uganda
# Name: Country, dtype: object

# %%
#data = pd.read_csv("/content/drive/MyDrive/udmy/dataAnalisys/Cities.csv", usecols = ["City", "Country"], index_col = "City")
data = pd.read_csv("/content/drive/MyDrive/udmy/dataAnalisys/Cities.csv", usecols = ["City", "Country"])
data.sort_index(inplace = True)
data
# Out:
#               City     Country
# 0           Kajuru    Botswana
# 1             Leon       Spain
# 2              Osh  kyrgyzstan
# 3    Shumikhinskiy      Russia
# 4         Bundoran     Ireland
# ..             ...         ...
# 596        Lobitos        Peru
# 597         Bremen     Germany
# 598         Harare    Zimbabwe
# 599          Lagos     Nigeria
# 600         Oshawa      Canada
#
# [601 rows x 2 columns]

# %%
city = data["City"]
city
# Out:
# 0             Kajuru
# 1               Leon
# 2                Osh
# 3      Shumikhinskiy
# 4           Bundoran
#            ...
# 596          Lobitos
# 597           Bremen
# 598           Harare
# 599            Lagos
# 600           Oshawa
# Name: City, Length: 601, dtype: object

# %%
city.get(3)
# Out:
# 'Shumikhinskiy'

# %%
city.get([1, 5])
city
# Out:
# 0             Kajuru
# 1               Leon
# 2                Osh
# 3      Shumikhinskiy
# 4           Bundoran
#            ...
# 596          Lobitos
# 597           Bremen
# 598           Harare
# 599            Lagos
# 600           Oshawa
# Name: City, Length: 601, dtype: object

# %%
#city.get(["Aizahai", "Alis"])
print(city.get(["Aizahai", "Alis"]))
# Out:
# None

# %%
print(city.get(780))
# Out:
# None

# %%
city.dtype      #To veriry that cuty is an object 'o'
# Out:
# dtype('O')

# %%
city.values
# Out:
# array(['Kajuru', 'Leon', 'Osh', 'Shumikhinskiy', 'Bundoran', 'La Paloma',
#        'Tutup', 'Ondores', 'Heredia', 'Gaio', 'Ise', 'Volovo', 'Caujul',
#        'Kutloanong', 'Kobuleti', 'Senlis', 'Wufeng', 'Picton',
#        'Johor Bahru', 'Fort Worth', 'Santa Cruz', 'Lope de Vega',
#        'Maubin', 'El Crucero', 'Itzer', 'Erqu', 'Los Cerrillos', 'Uptar',
#        'Ponta do Sol', 'Boca de Uchire', 'Pagsanahan Norte',
#        'Khlong Luang', 'Dazhipo', 'Berezovo', 'Mahajanga', 'Hexi', 'Tuwa',
#        'Bawshar', 'Sundbyberg', 'Lattes', 'Ciyun', 'Bureng', 'Dahewan',
#        'Lobitos', 'Esso', 'Heshang', 'Luknovo', 'Ancahuasi',
#        'Ciudad Nueva', 'Claveria', 'Tiexi', 'Lisieux', 'Rennes', 'Ivoti',
#        'Santa Marta', 'Utkivka', 'Gombang', 'Panay', 'Saribudolok',
#        'Pervomayskiy', 'Pereiras', 'Fika', 'Sucre', 'Hengdaohezi',
#        'Sinegorskiy', 'Strazhitsa', 'Aizhai', 'Marco', 'Donskoye',
#        'Zhongshangang', 'Colomi', 'Sabbah', 'San Carlos de Bariloche',
# ...

# %%
population = pop
population
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-104-91427981dfb7> in <cell line: 0>()
# ----> 1 population = pop
#       2 population
#
# NameError: name 'pop' is not defined

# %%
population = pop["Population"]
population
# Out:
# 0      21722
# 1       5629
# 2       5679
# 3      10085
# 4      23421
#        ...
# 596    10024
# 597     5768
# 598    16679
# 599    24800
# 600    13000
# Name: Population, Length: 601, dtype: int64

# %%
population.dtype() ### Revisar por que no funciona
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-116-882a6d4fc6b2> in <cell line: 0>()
# ----> 1 population.dtype()
#
# TypeError: 'numpy.dtypes.Int64DType' object is not callable

# %%
#pop.values
#population.values
population.describe()
# Out:
# count      601.000000
# mean     13932.415973
# std       6765.873291
# min       2528.000000
# 25%       7801.000000
# 50%      13966.000000
# 75%      19752.000000
# max      38745.000000
# Name: Population, dtype: float64

# %%
city.index
# Out:
# RangeIndex(start=0, stop=601, step=1)

# %%
population.index
# Out:
# RangeIndex(start=0, stop=601, step=1)

# %%
city.is_unique
# Out:
# False

# %%
population.is_unique
# Out:
# False

# %%
city.ndim
# Out:
# 1

# %%
#pop.ndim
population.ndim
# Out:
# 0      21722
# 1       5629
# 2       5679
# 3      10085
# 4      23421
#        ...
# 596    10024
# 597     5768
# 598    16679
# 599    24800
# 600    13000
# Name: Population, Length: 601, dtype: int64

# %%
info.ndim
# Out:
# 2
